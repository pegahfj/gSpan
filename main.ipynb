# %%
from gspan_mining.config import parser
from gspan_mining.main import main

# %%
# %pylab inline

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx

# %%
args_str = '-s 2 -d True -l 5 -p True -w True graphdata/graph.data.simple.5'
FLAGS, _ = parser.parse_known_args(args=args_str.split())

# %%
gs = main(FLAGS)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 gs = main(FLAGS)
#
# File ~/Desktop/BachelorProject/BSc2024/subGraphDevelopement/betterenvi/gSpan/gspan_mining/main.py:36, in main(FLAGS)
#      22     sys.exit()
#      24 gs = gSpan(
#      25     database_file_name=FLAGS.database_file_name,
#      26     min_support=FLAGS.min_support,
#    (...)
#      33     where=FLAGS.where
#      34 )
# ---> 36 gs.run()
#      37 gs.time_stats()
#      38 gs.save_results('output.txt')
#
# File ~/Desktop/BachelorProject/BSc2024/subGraphDevelopement/betterenvi/gSpan/gspan_mining/gspan.py:24, in record_timestamp.<locals>.deco(self)
#      22 def deco(self):
#      23     self.timestamps[func.__name__ + '_in'] = time.time()
# ---> 24     func(self)
#      25     self.timestamps[func.__name__ + '_out'] = time.time()
#
# File ~/Desktop/BachelorProject/BSc2024/subGraphDevelopement/betterenvi/gSpan/gspan_mining/gspan.py:321, in gSpan.run(self)
#     319 for vevlb, projected in root.items():
#     320     self._DFScode.append(DFSedge(0, 1, vevlb))
# --> 321     self._subgraph_mining(projected)
#     322     self._DFScode.pop()
#
# File ~/Desktop/BachelorProject/BSc2024/subGraphDevelopement/betterenvi/gSpan/gspan_mining/gspan.py:535, in gSpan._subgraph_mining(self, projected)
#     533 num_vertices = self._DFScode.get_num_vertices()
#     534 self._DFScode.build_rmpath()
# --> 535 rmpath = self._DFScode.rmpatopenh
#     536 maxtoc = self._DFScode[rmpath[0]].to
#     537 min_vlb = self._DFScode[0].vevlb[0]
#
# AttributeError: 'DFScode' object has no attribute 'rmpatopenh'

# %% [markdown]
# ## plot graphs in database

# %%
for g in gs.graphs.values():
    g.plot()
